# %%
# %run P3Utils.py

# %%
q0 = (0,0)
qgoal = (10,10)

obs1 = Obstacle((1,1),1,4)
obs2 = Obstacle((3,4),1,8)
obs3 = Obstacle((3,12),9,1)
obs4 = Obstacle((12,5),1,8)
obs5 = Obstacle((6,5),6,1)
obstacles = [obs1,obs2,obs3,obs4,obs5]
WF = WaveFront(q0, qgoal, obstacles)

# %%
WF.plot_path()
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <AxesSubplot:title={'center':'WaveFront Path'}>)

# %%
q0 = (0,0)
qgoal = (35,0)
obs1 = Obstacle((-6,-6),25-(-6),1)
obs2 = Obstacle((-6,5),30-(-6),1)
obs3 = Obstacle((-6,-5),1,10)
obs4 = Obstacle((4,-5),1,6)
obs5 = Obstacle((9,0),1,5)
obs6 = Obstacle((14,-5),1,6)
obs7 = Obstacle((19,0),1,5)
obs8 = Obstacle((24,-5),1,6)
obs9 = Obstacle((29,0),1,5)
obstacles = [obs1,obs2,obs3,obs4,obs5,obs6,obs7,obs8,obs9]

WF = WaveFront(q0, qgoal, obstacles)

# %%
WF.plot_path()
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <AxesSubplot:title={'center':'WaveFront Path'}>)
