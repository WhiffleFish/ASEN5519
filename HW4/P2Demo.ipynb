# %%
# %run P2Utils.py

# %%
PRM = PRMSolver(*load_env('A'))
PRM.sample(r=1,n=200)
PRM.plot()
# Out:
# 100%|██████████| 197/197 [00:01<00:00, 196.35it/s]
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 13.054'}>)

# %%
PRM.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 13.054'}>)

# %%
PRM.smooth_path(100)
PRM.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 10.0'}>)

# %%
PRM = PRMSolver(*load_env('B1'))
PRM.sample(r=2,n=200)
PRM.plot()
# Out:
# 100%|██████████| 163/163 [00:01<00:00, 113.75it/s]
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 14.771'}>)

# %%
PRM.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 14.771'}>)

# %%
PRM.smooth_path(100)
PRM.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 14.516'}>)

# %%
PRM = PRMSolver(*load_env('B2'))
PRM.sample(r=2,n=500)
PRM.plot()
# Out:
# 100%|██████████| 386/386 [00:07<00:00, 52.70it/s]
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 41.918'}>)

# %%
PRM.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 41.918'}>)

# %%
PRM.smooth_path(100)
PRM.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 38.306'}>)
