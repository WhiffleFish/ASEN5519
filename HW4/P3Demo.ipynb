# %%
# %run P3Utils.py

# %%
RRT = RRTSolver(*load_env('A'), pgoal=0.05, eps=0.25, max_iter=5000, step_size=0.5)
RRT.search()
RRT.plot(path_only=False)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 11.126'}>)

# %%
RRT = RRTSolver(*load_env('B1'), pgoal=0.05, eps=0.25, max_iter=5000, step_size=0.5)
RRT.search()
RRT.plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 18.078'}>)

# %%
RRT = RRTSolver(*load_env('B2'), pgoal=0.05, eps=0.25, max_iter=5000, step_size=0.5)
RRT.search()
RRT.plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 62.105'}>)
