# %%
# %run P3Utils.py

# %%
RRT = RRTSolver(*load_env('A'), pgoal=0.005)
RRT.search()
RRT.plot(path_only=True)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 12.101'}>)

# %%
RRT = RRTSolver(*load_env('B1'), pgoal=0.05)
RRT.search()
RRT.plot()
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 21.482'}>)

# %%
RRT = RRTSolver(*load_env('B2'), pgoal=0.05)
RRT.search()
RRT.plot(path_only=False)
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <AxesSubplot:title={'center':'Path Length: 46.387'}>)
