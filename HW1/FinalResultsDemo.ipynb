# %%
# %run bugs.py

# %%
qstart, qgoal, W = workspace1_data()
path, dist = BUG1(qstart,qgoal,W)
print("Path Distance:", dist)
fig, ax = plot_path(path,W)
ax.set_title("WORKSPACE 1 - BUG 1")
plt.show()
# Out:
# INFO:root:Goal Reached
# Path Distance: 108.0

# %%
path, dist = BUG2(qstart,qgoal,W)
print("Path Distance:", dist)
fig, ax = plot_path(path,W)
ax.set_title("WORKSPACE 1 - BUG 2")
plt.show()
# Out:
# INFO:root:Goal Reached
# Path Distance: 21.313708498984766

# %%
qstart, qgoal, W, extents, pad = workspace2_data(pad=6)
path, dist = BUG1(qstart,qgoal,W)
print("Path Distance:", dist)
fig, ax = plot_path(path,W,extents=extents,pad=pad)
ax.set_title("WORKSPACE 2 - BUG 1")
plt.show()
# Out:
# INFO:root:Goal Reached
# Path Distance: 317.0

# %%
path, dist = BUG2(qstart,qgoal,W)
print("Path Distance:", dist)
fig, ax = plot_path(path,W,extents=extents,pad=pad)
ax.set_title("WORKSPACE 2 - BUG 2")
plt.show()
# Out:
# INFO:root:Goal Reached
# Path Distance: 415.0
