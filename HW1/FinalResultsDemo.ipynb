# %%
# %run bugs.py

# %%
qstart, qgoal, W = workspace1_data()
path = BUG1(qstart,qgoal,W)
fig, ax = plot_path(path,W)
plt.show()
# Out:
# INFO:root:Goal Reached

# %%
path = BUG2(qstart,qgoal,W)
fig, ax = plot_path(path,W)
plt.show()
# Out:
# INFO:root:Goal Reached

# %%
qstart, qgoal, W, extents, pad = workspace2_data(pad=6)
path = BUG1(qstart,qgoal,W)
fig, ax = plot_path(path,W,extents=extents,pad=pad)
plt.show()
# Out:
# INFO:root:Goal Reached

# %%
path = BUG2(qstart,qgoal,W)
fig, ax = plot_path(path,W,extents=extents,pad=pad)
plt.show()
# Out:
# INFO:root:Goal Reached
