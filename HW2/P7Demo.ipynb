# %%
# %run P7.py

# %% [markdown]
# ## Specity length of each link and configuration

# %%
#Specify Lengths
l1 = 10
l2 = 10
l3 = 10

#Specify angles (radians)
theta1 = np.deg2rad(45)
theta2 = np.deg2rad(45)
theta3 = np.deg2rad(45)

final_pos = end_pos(theta1,theta2,theta3,l1,l2,l3)
print("Calculated End affector location:",final_pos)
plot_configuration(theta1, theta2, theta3, l1,l2,l3)
# Out:
# Calculated End affector location: (1.7763568394002505e-15, 24.14213562373095)

# %%
end_pos(*find_angles(0,4,8,8,9),8,8,9)
# Out:
# (1.064765775549148e-10, 4.00000000003109)

# %%
plot_configuration(*find_angles(20,20,10,10,10),10,10,10)

# %%
end_pos(*find_angles(30,0,10,10,10),10,10,10)
# Out:
# (30.0, 0.0)

# %% [markdown]
# ## Specify length of each link and end point location

# %%
#Specify Lengths
l1 = 10
l2 = 10
l3 = 10

#Specify desired end affector location
x = 30
y = 0

angles = find_angles(x,y,l1,l2,l3, maxfev=4000)
print("Angles:", *np.rad2deg(angles))
plot_configuration(*angles,l1,l2,l3)
# Out:
# Angles: 0.0 0.0 0.0
