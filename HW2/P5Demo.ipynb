# %% [markdown]
# # PROBLEM 5

# %%
# %run P5.py

# %%
# Define Obstacle and robot vertices
Vobs = np.array([[0,0],[1,2],[0,2]])
Vrob = np.array([[-1,-2],[0,-2],[0,0]])

# %%
verts = Cspace_vertices(Vobs, Vrob)
plot_Cspace_vertices(verts)

# %%
vert_dist = Cspace_vertices_distribution(Vobs, Vrob)
plot_Cspace_dist(vert_dist)
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <mpl_toolkits.mplot3d.axes3d.Axes3D at 0x81569db10>)
