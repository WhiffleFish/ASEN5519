# %% [markdown]
# # PROBLEM 3

# %%
# %run P3.py

# %%
t1,t2,t3 = get_all_angles(0,4)

# %%
scatter_angles(t1,t2,t3)
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1016af7490>)
