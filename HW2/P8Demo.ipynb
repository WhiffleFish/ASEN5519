# %% [markdown]
# # PROBLEM 8

# %%
# %run P8.py

# %% [markdown]
# # A

# %%
verts = np.array([[0.25,0.25],[0,0.75],[-0.25,0.25]])
plot_workspace(verts)
plt.show()

# %%
obstacles = get_obstacles(verts)
Cspace_grid = to_CSpace(obstacles)
# Out:
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %

# %%
plot_CSpace(Cspace_grid)
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11eeb3ed0>)

# %% [markdown]
# # B

# %%
verts1 = np.array([[-0.25,1.1],[-0.25,2],[0.25,2],[0.25,1.1]])
verts2 = np.array([[-2,-2],[-2,-1.8],[2,-1.8],[2,-2]])
plot_workspace(verts1,verts2)
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11fc2b8d0>)

# %%
obstacles = get_obstacles(verts1,verts2)
Cspace_grid = to_CSpace(obstacles)
plot_CSpace(Cspace_grid)
# Out:
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# (<Figure size 864x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11fdd1f90>)

# %% [markdown]
# # C

# %%
verts1 = np.array([[-0.25,1.1],[-0.25,2],[0.25,2],[0.25,1.1]])
verts2 = np.array([[-2,-0.5],[-2,-0.3],[2,-0.3],[2,-0.5]])
obstacles = get_obstacles(verts1,verts2)
plot_workspace(verts1,verts2)
# Out:
# (<Figure size 864x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11ff50950>)

# %%
Cspace_grid = to_CSpace(obstacles)
plot_CSpace(Cspace_grid)
# Out:
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# (<Figure size 864x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11e86d250>)
